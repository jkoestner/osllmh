# %% [markdown]
# # Import Modules

# %%
import importlib
import os
import sys

import pandas as pd

os.chdir("../")
os.getcwd()
# import working directory before going to other locations
sys.path.insert(0, os.getcwd())

# %%
from osllmh import engine, vector_stores
from osllmh.utils import custom_logger

# %%
# update log level if wanting more logging
custom_logger.set_log_level("DEBUG")

# %% [markdown]
# # Engine

# %% [markdown]
# ## Create Engine

# %%
e = engine.Engine()
# Out:
#  2025-03-21 09:53:56 | osllmh.engine | INFO     | Loaded settings with project: `actuary`, vector_type: `qdrant`, and url...
#  2025-03-21 09:53:56 | osllmh.engine | INFO     | Setting up the tokenizer...
#  2025-03-21 09:53:56 | osllmh.engine | INFO     | Loading existing index from storage...
#  2025-03-21 09:53:56 | osllmh.engine | INFO     | Creating response synthesizer with reponse_mode: compact...
#  2025-03-21 09:53:56 | osllmh.engine | INFO     | Creating query engine...
#  2025-03-21 09:53:56 | osllmh.engine | INFO     | Using custom prompt: compact...

# %%
settings = e.get_settings()
settings

# %%
# update project
settings['project']['name']='personal'
settings = e.update_settings(settings_path=settings)

# %%
# create_index will actually update or create
e.create_index()

# %%
response = e.query("what is the best sentence")

# %%
response.response

# %% [markdown]
# ## Vector Maintenance

# %%
e.vector_provider.list_files_from_index()

# %%
e.vector_provider.client.get_collections()

# %%
# e.vector_provider.delete_index()

# %%
# e.vector_provider.delete_document('a4261775-f0b7-403d-9691-08400eb593e7')

# %% [markdown]
# # Reload

# %%
import importlib

# %%
importlib.reload(engine)
importlib.reload(vector_stores)
# Out:
# <module 'osllmh.vector_stores' from 'C:\\Users\\johnk\\Desktop\\github\\osllmh\\osllmh\\vector_stores.py'>

# %% [markdown]
# # Test
